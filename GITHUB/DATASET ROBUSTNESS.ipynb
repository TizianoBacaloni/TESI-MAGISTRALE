# %%
import pandas as pd
from statsmodels.tsa.stattools import adfuller
import numpy as np
from numpy.linalg import inv
import statsmodels.api as sm
import pandas as pd
import re
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('/Users/tiziana/Desktop/PYTHON/TESI MAGISTRALE/DATI/DATABASE FINALE/DATABASE  ROBUSTO ULTIMATO.csv')
df.head()
# Out:
#          Country Trimestre  Real house price index  Price-Income Ratio  \
# 0  United States    2000Q1               -0.740957           -0.507019
# 1  United States    2000Q2               -0.740683           -0.511630
# 2  United States    2000Q3               -0.885000           -0.675248
# 3  United States    2000Q4               -0.818637           -0.616557
# 4  United States    2001Q1               -0.785615           -0.540603
#
#    LT interest rate    Spread  Credit to private NF sector  \
# 0               0.0 -0.044442                    -2.265956
# 1               0.0 -0.025998                    -2.165971
# 2               0.0  0.082732                    -2.110424
# 3               0.0  0.102147                    -2.054877
# 4               0.0  0.326555                    -2.099315
#
#    Stock idx open-price  Share price  Gdp growth  Current Account  \
# 0             -0.475456    -0.926780    0.358644        -0.285461
# ...

# %%
df1 = pd.read_csv('/Users/tiziana/Desktop/PYTHON/TESI MAGISTRALE/DATI/DATABASE FINALE/DATABASE ULTIMATO.csv')

# %%
df.set_index('Country',inplace=True)
for nazione in df.index:

    nazionali = df.loc[nazione]
    trimestri = len(nazionali['Trimestre'])

    print(f' per {nazione} ci sono {trimestri} trimestri')

df.reset_index(inplace=True)
# Out:
#  per United States ci sono 92 trimestri
#  per United States ci sono 92 trimestri
#  per United States ci sono 92 trimestri
#  per United States ci sono 92 trimestri
#  per United States ci sono 92 trimestri
#  per United States ci sono 92 trimestri
#  per United States ci sono 92 trimestri
#  per United States ci sono 92 trimestri
#  per United States ci sono 92 trimestri
#  per United States ci sono 92 trimestri
#  per United States ci sono 92 trimestri
#  per United States ci sono 92 trimestri
#  per United States ci sono 92 trimestri
#  per United States ci sono 92 trimestri
#  per United States ci sono 92 trimestri
#  per United States ci sono 92 trimestri
#  per United States ci sono 92 trimestri
#  per United States ci sono 92 trimestri
#  per United States ci sono 92 trimestri
#  per United States ci sono 92 trimestri
#  per United States ci sono 92 trimestri
#  per United States ci sono 92 trimestri
#  per United States ci sono 92 trimestri
# ...

# %%
df1.set_index('Country',inplace=True)

for nazione in df1.index:

    nazionali = df1.loc[nazione]
    trimestri = len(nazionali['Trimestre'])

    print(f' per {nazione} ci sono {trimestri} trimestri')


df1.reset_index(inplace=True)
# Out:
#  per United States ci sono 92 trimestri
#  per United States ci sono 92 trimestri
#  per United States ci sono 92 trimestri
#  per United States ci sono 92 trimestri
#  per United States ci sono 92 trimestri
#  per United States ci sono 92 trimestri
#  per United States ci sono 92 trimestri
#  per United States ci sono 92 trimestri
#  per United States ci sono 92 trimestri
#  per United States ci sono 92 trimestri
#  per United States ci sono 92 trimestri
#  per United States ci sono 92 trimestri
#  per United States ci sono 92 trimestri
#  per United States ci sono 92 trimestri
#  per United States ci sono 92 trimestri
#  per United States ci sono 92 trimestri
#  per United States ci sono 92 trimestri
#  per United States ci sono 92 trimestri
#  per United States ci sono 92 trimestri
#  per United States ci sono 92 trimestri
#  per United States ci sono 92 trimestri
#  per United States ci sono 92 trimestri
#  per United States ci sono 92 trimestri
# ...

# %%
df1.set_index(['Country','Trimestre'],inplace=True)
df.set_index(['Country','Trimestre'],inplace=True)

# %%
jp=df.loc['Japan']

# %%
jp1=df1.loc['Japan']

# %%
jp.index
# Out:
# Index(['2000Q1', '2000Q2', '2000Q3', '2000Q4', '2001Q1', '2001Q2', '2001Q3',
#        '2001Q4', '2002Q1', '2002Q2', '2002Q3', '2002Q4', '2003Q1', '2003Q2',
#        '2003Q3', '2003Q4', '2004Q1', '2004Q2', '2004Q3', '2004Q4', '2005Q1',
#        '2005Q2', '2005Q3', '2005Q4', '2006Q1', '2006Q2', '2006Q3', '2006Q4',
#        '2007Q1', '2007Q2', '2007Q3', '2007Q4', '2008Q1', '2008Q2', '2008Q3',
#        '2008Q4', '2009Q1', '2009Q2', '2009Q3', '2009Q4', '2010Q1', '2010Q2',
#        '2010Q3', '2010Q4', '2011Q1', '2011Q2', '2011Q3', '2011Q4', '2012Q1',
#        '2012Q2', '2012Q3', '2012Q4', '2013Q1', '2013Q2', '2013Q3', '2013Q4',
#        '2014Q1', '2014Q2', '2014Q3', '2014Q4', '2015Q1', '2015Q2', '2015Q3',
#        '2015Q4', '2016Q1', '2016Q2', '2016Q3', '2016Q4', '2017Q1', '2017Q2',
#        '2017Q3', '2017Q4', '2018Q1', '2018Q2', '2018Q3', '2018Q4', '2019Q1',
#        '2019Q2', '2019Q3', '2019Q4', '2020Q1', '2020Q2', '2020Q3', '2020Q4',
#        '2021Q1', '2021Q2'],
# ...

# %%
jp1.index
# Out:
# Index(['2000Q1', '2000Q2', '2000Q3', '2000Q4', '2001Q1', '2001Q2', '2001Q3',
#        '2001Q4', '2002Q1', '2002Q2', '2002Q3', '2002Q4', '2003Q1', '2003Q2',
#        '2003Q3', '2003Q4', '2004Q1', '2004Q2', '2004Q3', '2004Q4', '2005Q1',
#        '2005Q2', '2005Q3', '2005Q4', '2006Q1', '2006Q2', '2006Q3', '2006Q4',
#        '2007Q1', '2007Q2', '2007Q3', '2007Q4', '2008Q1', '2008Q2', '2008Q3',
#        '2008Q4', '2009Q1', '2009Q2', '2009Q3', '2009Q4', '2010Q1', '2010Q2',
#        '2010Q3', '2010Q4', '2011Q1', '2011Q2', '2011Q3', '2011Q4', '2012Q1',
#        '2012Q2', '2012Q3', '2012Q4', '2013Q1', '2013Q2', '2013Q3', '2013Q4',
#        '2014Q1', '2014Q2', '2014Q3', '2014Q4', '2015Q1', '2015Q2', '2015Q3',
#        '2015Q4', '2016Q1', '2016Q2', '2016Q3', '2016Q4', '2017Q1', '2017Q2',
#        '2017Q3', '2017Q4', '2018Q1', '2018Q2', '2018Q3', '2018Q4', '2019Q1',
#        '2019Q2', '2019Q3', '2019Q4', '2020Q1', '2020Q2', '2020Q3', '2020Q4',
# ...

# %%
df1 = df1.drop(('Japan', '2022Q1'))
df1 = df1.drop(('Japan', '2021Q4'))
df1 = df1.drop(('Japan', '2021Q3'))

# %%
df1
# Out:
#                          Real house price index  Price-Income Ratio  \
# Country       Trimestre
# United States 2000Q1                  -0.740957           -0.507019
#               2000Q2                  -0.740683           -0.511630
#               2000Q3                  -0.885000           -0.675248
#               2000Q4                  -0.818637           -0.616557
#               2001Q1                  -0.785615           -0.540603
# ...                                         ...                 ...
# Germany       2021Q4                   2.389218            1.341601
#               2022Q1                   2.612958            1.895590
#               2022Q2                   2.750616            2.119814
#               2022Q3                   2.641227            1.924850
#               2022Q4                   2.594136            1.841480
#
#                          LT interest rate    Spread  \
# Country       Trimestre
# ...

# %%
df_robusto = df
df_robusto.reset_index(inplace=True)
infl = df_robusto['Inflation rate']

# %%
dataset_pca = pd.read_csv('/Users/tiziana/Desktop/PYTHON/TESI MAGISTRALE/PCA/DATESET.csv')
dataset_pca.head()

dataset_pca.set_index(['Country','Trimestre'],inplace=True)
dataset_pca = dataset_pca.drop(('Japan', '2022Q1'))
dataset_pca = dataset_pca.drop(('Japan', '2021Q4'))
dataset_pca = dataset_pca.drop(('Japan', '2021Q3'))

dataset_pca.reset_index(inplace=True)

# %%
dataset_pca['Inflation rate']=infl

# %%
dataset_pca
# Out:
#             Country Trimestre  Unnamed: 0  Gdp growth  Current Account  \
# 0     United States    2000Q1           0    0.358644        -0.285461
# 1     United States    2000Q2           1   -0.302539        -0.264238
# 2     United States    2000Q3           2   -0.280988        -0.485583
# 3     United States    2000Q4           3   -0.051483        -0.503708
# 4     United States    2001Q1           4    0.246309        -0.518578
# ...             ...       ...         ...         ...              ...
# 1201        Germany    2021Q4        1204    0.055749         0.251848
# 1202        Germany    2022Q1        1205    0.294143        -0.172778
# 1203        Germany    2022Q2        1206   -0.494755        -0.512926
# 1204        Germany    2022Q3        1207    0.314331        -0.437565
# 1205        Germany    2022Q4        1208    0.109709        -0.328609
#
#       Public Debt  Financial index  Inflation rate
# 0       -1.210698        -1.165517        0.413990
# ...

# %%
dataset_pca.to_csv('Dataset_robusto_pca.csv')
